# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
leads_basic_details=pd.read_csv(r"D:\Competisun DA Assignment\Dataset\leads_basic_details.csv")

# %%
leads_basic_details.head()
# Out:
#    lead_id  age  gender   current_city current_education    parent_occupation  \
# 0  USR1001   16  FEMALE      Hyderabad      Intermediate     Private Employee
# 1  USR1002   20    MALE      Bengaluru            B.Tech             Business
# 2  USR1003   20  FEMALE  Visakhapatnam            B.Tech               Lawyer
# 3  USR1004   16    MALE         Mumbai      Intermediate          IT Employee
# 4  USR1005   16    MALE        Chennai      Intermediate  Government Employee
#
#   lead_gen_source
# 0    social_media
# 1  user_referrals
# 2  user_referrals
# 3  user_referrals
# 4  user_referrals

# %%
#getting  two outliers in age

# %%
sns.boxplot(data=leads_basic_details,x='age')
# Out:
# <Axes: xlabel='age'>

# %%
leads_basic_details[leads_basic_details['age']>25]
# Out:
#      lead_id  age  gender current_city current_education parent_occupation  \
# 17   USR1018  211    MALE    Hyderabad            Degree       IT Employee
# 300  USR1301  116  FEMALE    Hyderabad      Intermediate  Private Employee
#
#     lead_gen_source
# 17     social_media
# 300    social_media

# %%
#removing outliers

# %%
leads_basic_details=leads_basic_details[leads_basic_details['age']<=25]

# %%
leads_basic_details.to_csv("leads_basic_details")

# %%
for i in leads_basic_details.columns:
    print(i)
    print(leads_basic_details[i].unique())
    print()
# Out:
# lead_id
# ['USR1001' 'USR1002' 'USR1003' 'USR1004' 'USR1005' 'USR1006' 'USR1007'
#  'USR1008' 'USR1009' 'USR1010' 'USR1011' 'USR1012' 'USR1013' 'USR1014'
#  'USR1015' 'USR1016' 'USR1017' 'USR1019' 'USR1020' 'USR1021' 'USR1022'
#  'USR1023' 'USR1024' 'USR1025' 'USR1026' 'USR1027' 'USR1028' 'USR1029'
#  'USR1030' 'USR1031' 'USR1032' 'USR1033' 'USR1034' 'USR1035' 'USR1036'
#  'USR1037' 'USR1038' 'USR1039' 'USR1040' 'USR1041' 'USR1042' 'USR1043'
#  'USR1044' 'USR1045' 'USR1046' 'USR1047' 'USR1048' 'USR1049' 'USR1050'
#  'USR1051' 'USR1052' 'USR1053' 'USR1054' 'USR1055' 'USR1056' 'USR1057'
#  'USR1058' 'USR1059' 'USR1060' 'USR1061' 'USR1062' 'USR1063' 'USR1064'
#  'USR1065' 'USR1066' 'USR1067' 'USR1068' 'USR1069' 'USR1070' 'USR1071'
#  'USR1072' 'USR1073' 'USR1074' 'USR1075' 'USR1076' 'USR1077' 'USR1078'
#  'USR1079' 'USR1080' 'USR1081' 'USR1082' 'USR1083' 'USR1084' 'USR1085'
#  'USR1086' 'USR1087' 'USR1088' 'USR1089' 'USR1090' 'USR1091' 'USR1092'
# ...

# %%
leads_demo_watched_details=pd.read_csv(r"D:\Competisun DA Assignment\Dataset\leads_demo_watched_details.csv")

# %%
leads_demo_watched_details.head()
# Out:
#    lead_id demo_watched_date language  watched_percentage
# 0  USR1002          1/4/2022   Telugu                  42
# 1  USR1003          1/7/2022   Telugu                  81
# 2  USR1004          1/2/2022   Telugu                  35
# 3  USR1005          1/3/2022    Hindi                  38
# 4  USR1006         1/12/2022    Hindi                  54

# %%
sns.boxplot(x='watched_percentage',data=leads_demo_watched_details)
# Out:
# <Axes: xlabel='watched_percentage'>

# %%
#findout Two outliers in this watched percentage

# %%
leads_demo_watched_details[leads_demo_watched_details['watched_percentage']>100]
# Out:
#      lead_id demo_watched_date language  watched_percentage
# 94   USR1138         2/20/2022  English                 510
# 133  USR1213         1/20/2022   Telugu                 233

# %%
#removing outliers

# %%
leads_demo_watched_details=leads_demo_watched_details[leads_demo_watched_details['watched_percentage']<=100]

# %%
leads_demo_watched_details.to_csv("leads_demo_watched_details")

# %%
leads_interaction_details=pd.read_csv(r"D:\Competisun DA Assignment\Dataset\leads_interaction_details.csv")

# %%
leads_interaction_details
# Out:
#       jnr_sm_id  lead_id lead_stage call_done_date   call_status  \
# 0     JNR1001MG  USR1001       lead       1/2/2022    successful
# 1     JNR1001MG  USR1001       lead       1/2/2022    successful
# 2     JNR1001MG  USR1002       lead       1/3/2022    successful
# 3     JNR1001MG  USR1002       lead       1/4/2022    successful
# 4     JNR1001MG  USR1002  awareness       1/5/2022    successful
# ...         ...      ...        ...            ...           ...
# 2187  JNR1001MG  USR1356       lead      2/21/2022  unsuccessful
# 2188  JNR1001MG  USR1357       lead       1/8/2022  unsuccessful
# 2189  JNR1001MG  USR1358       lead      1/12/2022  unsuccessful
# 2190  JNR1001MG  USR1359       lead      1/22/2022  unsuccessful
# 2191  JNR1001MG  USR1360       lead      2/21/2022  unsuccessful
#
#              call_reason
# 0      lead_introduction
# 1          demo_schedule
# 2      lead_introduction
# 3          demo_schedule
# 4     post_demo_followup
# ...                  ...
# ...

# %%
leads_reasons_for_no_interest=pd.read_csv(r"D:\Competisun DA Assignment\Dataset\leads_reasons_for_no_interest.csv")

# %%
leads_reasons_for_no_interest
# Out:
#      lead_id reasons_for_not_interested_in_demo  \
# 0    USR1001                No time for student
# 1    USR1003                                NaN
# 2    USR1004                                NaN
# 3    USR1005                                NaN
# 4    USR1006                                NaN
# ..       ...                                ...
# 289  USR1356                      Cannot afford
# 290  USR1357                      Cannot afford
# 291  USR1358              Wants offline classes
# 292  USR1359            Will join in final year
# 293  USR1360            Will join in final year
#
#     reasons_for_not_interested_to_consider  \
# 0                                      NaN
# 1                      No time for student
# 2                    Wants offline classes
# 3                             Can't afford
# 4         Student not interested in domain
# ..                                     ...
# 289                                    NaN
# ...

# %%
sales_managers_assigned_leads_details=pd.read_csv(r"D:\Competisun DA Assignment\Dataset\sales_managers_assigned_leads_details.csv")

# %%
sales_managers_assigned_leads_details
# Out:
#     snr_sm_id  jnr_sm_id assigned_date  cycle  lead_id
# 0    SNR501MG  JNR1001MG      1/1/2022      1  USR1001
# 1    SNR501MG  JNR1001MG      1/1/2022      1  USR1002
# 2    SNR501MG  JNR1001MG      1/1/2022      1  USR1003
# 3    SNR501MG  JNR1001MG      1/1/2022      1  USR1004
# 4    SNR501MG  JNR1001MG      1/1/2022      1  USR1005
# ..        ...        ...           ...    ...      ...
# 355  SNR501MG  JNR1001MG     2/19/2022      4  USR1356
# 356  SNR501MG  JNR1001MG      1/1/2022      1  USR1357
# 357  SNR501MG  JNR1001MG      1/8/2022      2  USR1358
# 358  SNR501MG  JNR1001MG     1/15/2022      3  USR1359
# 359  SNR501MG  JNR1001MG     2/19/2022      4  USR1360
#
# [360 rows x 5 columns]

# %%
sales_managers_assigned_leads_details.to_csv("sales_managers_assigned_leads_details")
